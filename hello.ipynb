# %%
import sys
print("Hello, Python!")
print("Python 버전:", sys.version)
print("실행 파일:", sys.executable)
# Out:
# Hello, Python!
# Python 버전: 3.13.15 (tags/v3.13.15:4061bc4, Aug  5 2026, 13:05:39) [MSC v.1944 64 bit (AMD64)]
# 실행 파일: c:\Users\Playdata\AppData\Local\Programs\Python\Python313\python.exe
